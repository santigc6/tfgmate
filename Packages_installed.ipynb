# %%
from sage.misc.package import list_packages
pkgs = list_packages(local=True, exclude_pip=False)  # optional - build
for key in sorted(pkgs.keys()):
    print("\item "+str(key)+": "+str(pkgs[key]))
# Out:
# \item 4ti2: {'remote_version': '1.6.7.p0', 'installed_version': None, 'type': 'optional', 'name': '4ti2', 'installed': False}
# \item alabaster: {'remote_version': '0.7.12', 'installed_version': '0.7.12', 'type': 'standard', 'name': 'alabaster', 'installed': True}
# \item appnope: {'remote_version': '0.1.0.p0', 'installed_version': '0.1.0.p0', 'type': 'standard', 'name': 'appnope', 'installed': True}
# \item arb: {'remote_version': '2.16.0.p0', 'installed_version': '2.16.0.p0', 'type': 'standard', 'name': 'arb', 'installed': True}
# \item atlas: {'remote_version': '3.10.2.p3', 'installed_version': None, 'type': 'optional', 'name': 'atlas', 'installed': False}
# \item autotools: {'remote_version': '20141105.p0', 'installed_version': None, 'type': 'experimental', 'name': 'autotools', 'installed': False}
# \item awali: {'remote_version': '1.0.2-190218', 'installed_version': None, 'type': 'optional', 'name': 'awali', 'installed': False}
# ...

# %%
from sage.misc.package import list_packages
pkgs = list_packages(exclude_pip=False)  # optional - build
for key in sorted(pkgs.keys()):
    if pkgs[key]['installed'] == True:
        print("\item "+str(key)+": "+str(pkgs[key]['installed_version']))
# Out:
# \item alabaster: 0.7.12
# \item appnope: 0.1.0.p0
# \item arb: 2.16.0.p0
# \item babel: 2.6.0
# \item backports_abc: 0.5
# \item backports_functools_lru_cache: 1.5
# \item backports_shutil_get_terminal_size: 1.0.0.p1
# \item backports_ssl_match_hostname: 3.5.0.1.p0
# \item bleach: 3.1.0
# \item boost_cropped: 1.66.0.p0
# \item brial: 1.2.5
# \item bzip2: 1.0.6-20150304.p0
# \item cddlib: 0.94j
# \item certifi: 2019.3.9
# \item cliquer: 1.21.p4
# \item combinatorial_designs: 20140630.p0
# \item configparser: 3.7.4
# \item conway_polynomials: 0.5
# \item curl: 7.62.0.p0
# \item cvxopt: 1.1.8.p2
# \item cycler: 0.10.0.p0
# \item cypari: 2.1.1
# \item cysignals: 1.10.2
# \item cython: 0.29.12.p0
# \item dateutil: 2.5.3
# \item decorator: 4.4.0
# \item defusedxml: 0.6.0
# \item docutils: 0.14
# \item ecl: 16.1.2.p5
# \item eclib: 20190226
# \item ecm: 7.0.4.p1
# \item elliptic_curves: 0.8.1
# \item entrypoints: 0.3
# \item enum34: 1.1.6
# \item fflas_ffpack: 2.4.3
# ...

# %%
import sklearn

sklearn.show_versions()
# Out:
# System:
#     python: 2.7.15 (default, Oct 18 2019, 17:33:39)  [GCC 7.4.0]
#    machine: Linux-4.15.0-96-generic-x86_64-with-debian-buster-sid
# executable: /home/santi/SageMath/local/bin/python2
#
# BLAS:
#     macros: HAVE_CBLAS=None
# cblas_libs: openblas, openblas
#   lib_dirs: /home/santi/SageMath/local/lib
#
# Python deps:
#     Cython: 0.29.12
#      scipy: 1.2.0
# setuptools: 40.6.3
#        pip: 18.1
#      numpy: 1.16.1
#     pandas: 0.24.2
#    sklearn: 0.20.4

# %%
import pandas as pd

pd.__version__
# Out:
# u'0.24.2'
